# %%
# ============================================================
# Cell 0: Install all dependencies (run once, then restart runtime)
# ============================================================
# !pip -q install --no-cache-dir \
  pymupdf==1.24.9 tqdm==4.66.5 \
  sentence-transformers==3.0.1 faiss-cpu==1.8.0 \
  langchain==0.2.16 langchain-community==0.2.16 langchain-text-splitters==0.2.2 \
  langchain-openai==0.1.23 \
  rank_bm25==0.2.2 \
  ragas==0.1.21 \
  openai>=1.40

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

BASE_DIR = "/content/drive/MyDrive/Kerala_DIRs"   # <-- this matches your screenshot
PDF_DIR = os.path.join(BASE_DIR, "01_canonical_pdfs")
MANIFEST_PATH = os.path.join(BASE_DIR, "10_manifests", "manifest_final.csv")

assert os.path.isdir(PDF_DIR), f"Missing PDF folder: {PDF_DIR}"
assert os.path.isfile(MANIFEST_PATH), f"Missing manifest: {MANIFEST_PATH}"

print("✅ Found PDF_DIR:", PDF_DIR)
print("✅ Found manifest:", MANIFEST_PATH)
# Out:
# ✅ Found PDF_DIR: /content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs
# ✅ Found manifest: /content/drive/MyDrive/Kerala_DIRs/10_manifests/manifest_final.csv

# %%
import pandas as pd

df = pd.read_csv(MANIFEST_PATH)

# Required columns
required_cols = {"doc_id", "canonical_filename"}
missing = required_cols - set(df.columns)
assert not missing, f"manifest_final.csv missing columns: {missing}"

# Build Drive paths using canonical_filename (ignore canonical_path because it's Windows)
df["pdf_path"] = df["canonical_filename"].apply(lambda fn: os.path.join(PDF_DIR, str(fn)))
df["pdf_exists"] = df["pdf_path"].apply(os.path.isfile)

print("Rows in manifest:", len(df))
print("PDFs found:", int(df["pdf_exists"].sum()))
print("PDFs missing:", int((~df["pdf_exists"]).sum()))

if (~df["pdf_exists"]).any():
    display(df.loc[~df["pdf_exists"], ["doc_id", "canonical_filename", "pdf_path"]].head(20))
# Out:
# Rows in manifest: 436
# PDFs found: 436
# PDFs missing: 0

# %%
import fitz  # PyMuPDF
from tqdm import tqdm

def extract_pages(pdf_path: str):
    pages = []
    with fitz.open(pdf_path) as doc:
        for i in range(len(doc)):
            text = doc.load_page(i).get_text("text") or ""
            text = text.strip()
            pages.append({"page": i+1, "text": text})
    return pages

# Smoke test: open one PDF
sample = df[df["pdf_exists"]].iloc[0]
pages = extract_pages(sample["pdf_path"])
print("Sample doc_id:", sample["doc_id"])
print("Pages:", len(pages))
print("First page chars:", len(pages[0]["text"]))
print(pages[0]["text"][:500])
# Out:
# Sample doc_id: KCDI000001
# Pages: 12
# First page chars: 2246
# Vol.:(0123456789)
# Journal of Industrial and Business Economics (2020) 47:519–530
# https://doi.org/10.1007/s40812-020-00170-x
# 1 3
# A critique of the Indian government’s response
# to the COVID-19 pandemic
# Jayati Ghosh1
# Received: 30 May 2020 / Revised: 2 July 2020 / Accepted: 3 July 2020 / Published online: 11 July 2020
# © Associazione Amici di Economia e Politica Industriale 2020
# Abstract
# The most destructive effects of Covid-19 in India have not been the result of the dis-
# ease, but the nature of

# %%
from langchain_core.documents import Document

def safe_get(row, col):
    if col in row and pd.notna(row[col]):
        return row[col]
    return ""

# Try to pick the most useful title for display:
# prefer original_filename if present, else title
def choose_display_title(row):
    orig = safe_get(row, "original_filename")
    title = safe_get(row, "title")
    return orig if str(orig).strip() else title

page_docs = []
failed = []

for _, row in tqdm(df[df["pdf_exists"]].iterrows(), total=int(df["pdf_exists"].sum())):
    pdf_path = row["pdf_path"]
    try:
        base_meta = {
            "doc_id": safe_get(row, "doc_id"),
            "canonical_filename": safe_get(row, "canonical_filename"),
            "display_title": choose_display_title(row),
            "year": safe_get(row, "year"),
            "doi": safe_get(row, "doi"),
            "geo_scope": safe_get(row, "geo_scope"),
            "metadata_confidence": safe_get(row, "metadata_confidence"),
            # Your sheet shows 2 metric columns (primary/secondary). Names can vary,
            # so we check a few possible column names safely.
            "metric_bucket_primary": safe_get(row, "metric_bucket_primary") or safe_get(row, "metric_buck_primary") or safe_get(row, "metric_bucket") or safe_get(row, "metric_buc"),
            "metric_bucket_secondary": safe_get(row, "metric_bucket_secondary") or safe_get(row, "metric_buck_secondary") or "",
            "sha256_hash": safe_get(row, "sha256_hash"),
            "file_size_bytes": safe_get(row, "file_size_bytes"),
            "source_folder": safe_get(row, "source_folder"),
        }

        pages = extract_pages(pdf_path)
        for p in pages:
            if not p["text"]:
                continue
            meta = dict(base_meta)
            meta["page"] = p["page"]
            meta["pdf_path"] = pdf_path  # traceability
            page_docs.append(Document(page_content=p["text"], metadata=meta))

    except Exception as e:
        failed.append((safe_get(row, "doc_id"), pdf_path, str(e)))

print("✅ Page-docs created:", len(page_docs))
print("❌ Failed PDFs:", len(failed))
failed[:5]
# Out:
# 100%|██████████| 436/436 [16:10<00:00,  2.23s/it]
# ✅ Page-docs created: 6307
# ❌ Failed PDFs: 39
# [('KCDI000007',
#   '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000007_.pdf',
#   "Failed to open file '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000007_.pdf'."),
#  ('KCDI000008',
#   '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000008_.pdf',
#   "Failed to open file '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000008_.pdf'."),
#  ('KCDI000030',
#   '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000030_.pdf',
#   "Failed to open file '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000030_.pdf'."),
#  ('KCDI000048',
#   '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000048_.pdf',
#   "Failed to open file '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000048_.pdf'."),
#  ('KCDI000054',
#   '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000054_.pdf',
#   "Failed to open file '/content/drive/MyDrive/Kerala_DIRs/01_canonical_pdfs/kcdi000054_.pdf'.")]

# %%
# ============================================================
# STEP 1: Improved Chunking (larger chunks for academic papers)
# ============================================================
# Academic papers have dense paragraphs — 1500 chars with 300 overlap
# keeps more context per chunk while still being under token limits.

from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=300,
    separators=["\n\n", "\n", ". ", " ", ""]  # added ". " to prefer sentence boundaries
)

chunk_docs = splitter.split_documents(page_docs)

# Store full page text as "parent_text" in metadata for parent-child retrieval later
page_lookup = {}
for doc in page_docs:
    key = (doc.metadata["doc_id"], doc.metadata["page"])
    page_lookup[key] = doc.page_content

for chunk in chunk_docs:
    key = (chunk.metadata["doc_id"], chunk.metadata["page"])
    chunk.metadata["parent_text"] = page_lookup.get(key, "")

print(f"Chunks created: {len(chunk_docs)}")
print(f"Avg chunk length: {sum(len(c.page_content) for c in chunk_docs) / len(chunk_docs):.0f} chars")
print(f"Parent pages indexed: {len(page_lookup)}")
# Out:
# Chunks created: 19555
# Avg chunk length: 1263 chars
# Parent pages indexed: 6307

# %%
# ============================================================
# STEP 2: Upgraded Embedding Model + FAISS Index
# ============================================================
# bge-base-en-v1.5 is a much stronger retrieval model than MiniLM.
# It uses 768-dim embeddings and was trained specifically for retrieval.
# On Colab GPU this takes ~15-20 min for ~20k chunks.

from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

EMBEDDING_MODEL = "BAAI/bge-base-en-v1.5"

embeddings = HuggingFaceEmbeddings(
    model_name=EMBEDDING_MODEL,
    model_kwargs={"device": "cuda"},    # use GPU if available
    encode_kwargs={"normalize_embeddings": True}  # bge models need L2 normalization
)

# Build the FAISS index — this is the slow step (~15-20 min on GPU)
print(f"Embedding {len(chunk_docs)} chunks with {EMBEDDING_MODEL}...")
vectorstore = FAISS.from_documents(chunk_docs, embeddings)

# Save to Drive so you don't have to re-embed every session
INDEX_DIR = os.path.join(BASE_DIR, "faiss_index_bge_base")
vectorstore.save_local(INDEX_DIR)
print(f"FAISS index saved to: {INDEX_DIR}")
# Out:
# /tmp/ipython-input-3463782314.py:13: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   embeddings = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedding 19555 chunks with BAAI/bge-base-en-v1.5...
# FAISS index saved to: /content/drive/MyDrive/Kerala_DIRs/faiss_index_bge_base

# %%
# ============================================================
# STEP 2b: (OPTIONAL) Load saved index instead of re-embedding
# ============================================================
# After first run, you can skip the embedding step and load from Drive:
# Uncomment the lines below and SKIP cell 7 on subsequent runs.

# from langchain_community.embeddings import HuggingFaceEmbeddings
# from langchain_community.vectorstores import FAISS
#
# EMBEDDING_MODEL = "BAAI/bge-base-en-v1.5"
# embeddings = HuggingFaceEmbeddings(
#     model_name=EMBEDDING_MODEL,
#     model_kwargs={"device": "cuda"},
#     encode_kwargs={"normalize_embeddings": True}
# )
# INDEX_DIR = os.path.join(BASE_DIR, "faiss_index_bge_base")
# vectorstore = FAISS.load_local(INDEX_DIR, embeddings, allow_dangerous_deserialization=True)
# print(f"Loaded FAISS index from: {INDEX_DIR}")

# %%
# ============================================================
# STEP 3: BM25 Retriever + Hybrid Ensemble
# ============================================================
# BM25 catches exact keyword matches (acronyms like MGNREGA, Kudumbashree,
# LSG, CDS) that dense embeddings often miss. EnsembleRetriever combines both.

from langchain.retrievers import EnsembleRetriever
from langchain_community.retrievers import BM25Retriever

# Build BM25 index over the same chunks
print("Building BM25 index...")
bm25_retriever = BM25Retriever.from_documents(chunk_docs, k=25)

# Dense retriever from FAISS
dense_retriever = vectorstore.as_retriever(search_kwargs={"k": 25})

# Combine: 60% dense + 40% BM25
# (dense gets more weight because semantic matching is usually better,
#  but BM25 rescues keyword-specific queries)
ensemble_retriever = EnsembleRetriever(
    retrievers=[dense_retriever, bm25_retriever],
    weights=[0.6, 0.4]
)

print("Hybrid retriever ready (FAISS 60% + BM25 40%)")
# Out:
# Building BM25 index...
# Hybrid retriever ready (FAISS 60% + BM25 40%)

# %%
# ============================================================
# STEP 4: Cross-Encoder Reranker
# ============================================================
# The reranker takes the top-25 candidates from hybrid search and
# re-scores them with a cross-encoder (much more accurate but slower).
# We keep only the top-k after reranking.

from sentence_transformers import CrossEncoder
import numpy as np

RERANKER_MODEL = "cross-encoder/ms-marco-MiniLM-L-6-v2"
reranker = CrossEncoder(RERANKER_MODEL, max_length=512)

def retrieve_and_rerank(query: str, top_k: int = 6):
    """Hybrid retrieve -> cross-encoder rerank -> return top_k."""
    # Step 1: Get candidates from hybrid retriever
    candidates = ensemble_retriever.invoke(query)

    if not candidates:
        return []

    # Step 2: Score each candidate with cross-encoder
    pairs = [(query, doc.page_content) for doc in candidates]
    scores = reranker.predict(pairs)

    # Step 3: Sort by reranker score descending
    scored = list(zip(candidates, scores))
    scored.sort(key=lambda x: x[1], reverse=True)

    # Return top_k with scores attached
    results = []
    for doc, score in scored[:top_k]:
        doc.metadata["reranker_score"] = float(score)
        results.append(doc)

    return results

# Quick test
test_results = retrieve_and_rerank("What is the role of Kudumbashree in poverty reduction?")
print(f"Retrieved and reranked: {len(test_results)} chunks")
for i, doc in enumerate(test_results, 1):
    print(f"\n[{i}] score={doc.metadata['reranker_score']:.4f}  "
          f"doc={doc.metadata['doc_id']}  p.{doc.metadata['page']}")
    print(f"    {doc.page_content[:200]}...")
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# Retrieved and reranked: 6 chunks
#
# [1] score=5.6771  doc=KCDI000149  p.6
#     to a changing economic landscape and addressing the specific needs of its
# micro enterprise ventures. A recent study by SIDNET in several panchayats
# revealed that the Kudumbashree program has not sig...
#
# [2] score=4.3482  doc=KCDI000415  p.2
#     management. The situation assessment survey was conducted by
# women’s self-help groups called Kudumbashree. Kudumbashree,
# introduced in 1998 as a women-oriented poverty eradication
# mission in Kerala, h...
#
# [3] score=4.2506  doc=KCDI000149  p.2
#     Exchanges: The Interdisciplinary Research Journal
#
# 52
# Thelekkatte et al. Exchanges 2025 12(2), pp. 51-61
#
# Introduction
# The Kudumbashree Mission has been a major success in the Indian state
# of K...
#
# [4] score=4.1566  doc=KCDI000149  p.6
#     Exchanges: The Interdisciplinary Research Journal
#
# 56
# Thelekkatte et al. Exchanges 2025 12(2), pp. 51-61
#
# While Kudumbashree has achieved significant success in poverty
# alleviation, its microent...
#
# [5] score=4.1542  doc=KCDI000149  p.2
#     systems such as Panchayati Raj. During the same time, the People’s Plan
# campaign was making rounds, aiming to bring in democratic
# decentralisation on three fronts: administrative, fiscal, and politi...
#
# [6] score=3.6962  doc=KCDI000427  p.2
#     and scheduled tribes in Omassery, Kodanchery, Balussery, Panangad and Arikkulam grama
#
#
# 1 The rough meaning of the word ‘Kudumbasree’ is pro...

# %%
# ============================================================
# STEP 5: OpenAI LLM Generation with Citations
# ============================================================
import os
from getpass import getpass
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# Set your OpenAI API key (will prompt you securely)
if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass("Enter your OpenAI API key: ")

# Use gpt-4o-mini for cost efficiency; switch to "gpt-4o" for higher quality
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.1)

SYSTEM_PROMPT = """You are an expert research assistant specializing in Kerala community development,
local governance, decentralization, and Indian urban/rural development policy.

You answer questions using ONLY the provided source documents. Follow these rules strictly:

1. Base every claim on the provided sources. Cite using [doc_id, p.X] format after each claim.
2. If the sources do not contain enough information to answer, say so explicitly.
3. Synthesize information across multiple sources when relevant.
4. When sources disagree, note the disagreement and cite both sides.
5. Keep answers focused, well-structured, and academic in tone.
6. End with a "Sources Used" section listing all cited documents with their titles."""

def format_context(docs):
    """Format retrieved documents into a context string for the LLM."""
    context_parts = []
    for i, doc in enumerate(docs, 1):
        md = doc.metadata
        header = (f"[Source {i}] doc_id={md.get('doc_id','?')} | "
                  f"page={md.get('page','?')} | "
                  f"title={str(md.get('display_title',''))[:100]} | "
                  f"year={md.get('year','?')} | "
                  f"geo={md.get('geo_scope','?')}")
        context_parts.append(f"{header}\n{doc.page_content}")
    return "\n\n---\n\n".join(context_parts)

prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("human", """Based on the following source documents, answer the question.

SOURCES:
{context}

QUESTION: {question}

Provide a thorough, well-cited answer:""")
])

chain = prompt | llm

print("LLM chain ready (gpt-4o-mini)")
# Out:
# Enter your OpenAI API key: ··········
# LLM chain ready (gpt-4o-mini)

# %%
# ============================================================
# STEP 6: Full RAG Pipeline (retrieve + rerank + generate)
# ============================================================

def rag_query(question: str, top_k: int = 6, verbose: bool = True):
    """End-to-end RAG: hybrid retrieve -> rerank -> LLM answer with citations."""

    # 1. Retrieve and rerank
    docs = retrieve_and_rerank(question, top_k=top_k)

    if not docs:
        return {"answer": "No relevant documents found.", "sources": [], "docs": []}

    # 2. Format context
    context = format_context(docs)

    # 3. Generate answer
    response = chain.invoke({"context": context, "question": question})
    answer = response.content

    # 4. Collect source info
    sources = []
    for doc in docs:
        md = doc.metadata
        sources.append({
            "doc_id": md.get("doc_id"),
            "page": md.get("page"),
            "title": str(md.get("display_title", ""))[:120],
            "year": md.get("year"),
            "reranker_score": md.get("reranker_score", 0),
        })

    if verbose:
        print("=" * 80)
        print(f"QUESTION: {question}")
        print("=" * 80)
        print(f"\n{answer}\n")
        print("-" * 40)
        print("Retrieved Sources (ranked by relevance):")
        for i, s in enumerate(sources, 1):
            print(f"  [{i}] {s['doc_id']} p.{s['page']} "
                  f"(score={s['reranker_score']:.3f}) — {s['title']}")

    return {"answer": answer, "sources": sources, "docs": docs}


# --- Try it! ---
result = rag_query("What indicators are used to measure municipal service delivery performance in Kerala?")
# Out:
# ================================================================================
# QUESTION: What indicators are used to measure municipal service delivery performance in Kerala?
# ================================================================================
#
# The sources provided do not specifically detail indicators used to measure municipal service delivery performance in Kerala. However, they do discuss various performance indicators in related sectors such as health care and irrigation, which can provide insights into the broader context of service delivery in the state.
#
# 1. **Health Care Indicators**: In the context of health care, a study focused on Universal Health Coverage (UHC) reforms in Kerala identified a set of 23 approved indicators for measuring primary health service coverage and system performance. These indicators include a mix of input, output, and outcome indicators, with specific categories addressing communicable diseases, non-communicable diseases (NCDs), reproductive, maternal, newborn, child, and adolescent health (RMNCAH), service delivery, and governance. Most of these indicators are intended to be measured at the facility level, with some at the district level, and include both monthly and annual measurements [doc_id=KCDI000224, p.8; KCDI000224, p.11].
#
# 2. **Water Supply Indicators**: In the realm of rural water supply, performance and sustainability indicators were developed to assess community-based approaches. The study found that participatory, community-driven water supply schemes were more effective in delivering adequate and quality water, experiencing fewer breakdowns, and achieving higher consumer satisfaction. This suggests that indicators related to service adequacy, reliability, and consumer satisfaction are critical for evaluating water service delivery [doc_id=KCDI000322, p.2].
#
# 3. **Irrigation Performance Indicators**: For minor irrigation schemes, performance assessment is crucial for effective service delivery. The evaluation of two minor irrigation schemes in Kozhikode district highlighted the use of external performance indicators that relate outputs to inputs in agriculture. These indicators help compare irrigation schemes and assess their effectiveness in terms of water delivery and maintenance [doc_id=KCDI000128, p.1; KCDI000128, p.2].
#
# In summary, while specific municipal service delivery indicators are not explicitly outlined in the provided documents, the indicators used in health care, water supply, and irrigation sectors reflect a broader framework for assessing service delivery performance in Kerala. These include measures of service adequacy, reliability, consumer satisfaction, and various health-related outcomes.
#
# **Sources Used**:
# 1. Monitoring Universal Health Coverage reforms in primary health care facilities Creating a framework (KCDI000224)
# 2. Sustainability of demand responsive approaches to rural water supply the case of Kerala (KCDI000322)
# 3. Evaluation of minor irrigation schemes using performance indicators case studies from South India (KCDI000128)
#
# ----------------------------------------
# Retrieved Sources (ranked by relevance):
#   [1] KCDI000224 p.11 (score=4.387) — Monitoring Universal Health Coverage reforms in primary health care facilities Creating a framework _W3047303743.pdf
#   [2] KCDI000322 p.2 (score=3.890) — Sustainability of demand responsive approaches to rural water supply  the case of Kerala_W3122568132.pdf
#   [3] KCDI000224 p.8 (score=3.564) — Monitoring Universal Health Coverage reforms in primary health care facilities Creating a framework _W3047303743.pdf
#   [4] KCDI000128 p.2 (score=3.364) — Evaluation of minor irrigation schemes using performance indicators case studies from South India_W2523646203.pdf
#   [5] KCDI000293 p.8 (score=1.856) — Sex differences in disease burden utilization and expenditure on primary health care services in Ker_W4410424587.pdf
#   [6] KCDI000128 p.1 (score=1.525) — Evaluation of minor irrigation schemes using performance indicators case studies from South India_W2523646203.pdf

# %%
# ============================================================
# STEP 6b: More example queries to test the pipeline
# ============================================================

queries = [
    "How does Kudumbashree contribute to women's empowerment and poverty alleviation?",
    "What are the main challenges in solid waste management in Kerala municipalities?",
    "How do studies measure road congestion or traffic conditions in Indian cities?",
    "What role do gram panchayats play in local governance and decentralization?",
    "What indicators measure electricity or water service reliability in Kerala?",
]

for q in queries:
    rag_query(q, top_k=5)
    print("\n\n")
# Out:
# ================================================================================
# QUESTION: How does Kudumbashree contribute to women's empowerment and poverty alleviation?
# ================================================================================
#
# Kudumbashree, a pioneering initiative launched by the Government of Kerala in 1997, plays a significant role in women's empowerment and poverty alleviation through a multifaceted approach that emphasizes economic independence, social mobility, and community engagement.
#
# 1. **Women-Centric Approach**: Kudumbashree is designed specifically to empower women, focusing on increasing their participation in the workforce and enhancing their socio-economic status. The program has successfully mobilized a network of four to five million women, directly and indirectly involved in various initiatives aimed at poverty eradication and gender equality [doc_id=KCDI000149, p.2].
#
# 2. **Economic Independence**: The initiative promotes women-led enterprises, which is particularly impactful in a region where such concepts were previously underdeveloped. By providing market-oriented training, financial aid, and post-launch support, Kudumbashree facilitates women's economic independence. This includes fostering skills necessary for entrepreneurship and creating pathways for women to engage in the market effectively [doc_id=KCDI000149, p.3; p.5].
#
# 3. **Targeted Outreach and Support**: Kudumbashree recognizes the challenges faced by women from underserved communities, including lower castes and tribal groups. To address these barriers, the program advocates for targeted outreach strategies, such as collaborating with community leaders and offering culturally sensitive training modules. This ensures that women from diverse backgrounds can fully participate in the program and benefit from its offerings [doc_id=KCDI000149, p.4].
#
# 4. **Comprehensive Support System**: The initiative aims to create a supportive ecosystem for women entrepreneurs by enhancing product quality and marketing strategies. This includes establishing marketing and sales teams to help women capture market share effectively. By addressing these operational challenges, Kudumbashree can further empower women and contribute to broader economic development [doc_id=KCDI000149, p.4; p.5].
#
# 5. **Social Mobility and Community Development**: Kudumbashree's focus on women's empowerment is not only about economic independence but also about fostering social mobility. By integrating women into the workforce and supporting their entrepreneurial ventures, the program contributes to the overall socio-economic transformation of communities in Kerala. This holistic approach aligns with the state's broader goals of poverty alleviation and gender equity [doc_id=KCDI000149, p.2; p.4].
#
# In conclusion, Kudumbashree significantly contributes to women's empowerment and poverty alleviation through its comprehensive, women-centric strategies that promote economic independence, targeted outreach, and community engagement. By addressing the specific needs of women, particularly those from marginalized backgrounds, the program enhances their participation in the economy and fosters sustainable development in Kerala.
#
# **Sources Used**:
# - Gender Equity and Women Empowerment_W4411231273.pdf
#
# ----------------------------------------
# Retrieved Sources (ranked by relevance):
#   [1] KCDI000149 p.2 (score=6.038) — Gender Equity and Women Empowerment_W4411231273.pdf
#   [2] KCDI000149 p.8 (score=5.999) — Gender Equity and Women Empowerment_W4411231273.pdf
#   [3] KCDI000149 p.2 (score=4.886) — Gender Equity and Women Empowerment_W4411231273.pdf
#   [4] KCDI000149 p.9 (score=4.847) — Gender Equity and Women Empowerment_W4411231273.pdf
#   [5] KCDI000149 p.1 (score=4.837) — Gender Equity and Women Empowerment_W4411231273.pdf
#
#
#
# ================================================================================
# QUESTION: What are the main challenges in solid waste management in Kerala municipalities?
# ================================================================================
#
# The challenges in solid waste management (SWM) in Kerala municipalities are multifaceted and stem from various socio-political, institutional, and community engagement issues.
#
# 1. **Community Participation**: One of the primary challenges is the lack of active community participation in waste management initiatives. Local authorities have struggled to mobilize communities and educate them on effective waste handling and storage techniques. This lack of engagement directly impacts the effectiveness of SWM initiatives, as community involvement is crucial for successful implementation [doc_id=KCDI000439, p.1].
#
# 2. **Ineffective Management Models**: Despite Kerala's advancements in education and health, the state still faces significant issues in effective waste management. Approximately 3.7 million tonnes of solid waste are generated annually, yet the absence of a successful management model exacerbates the problem. The existing systems have not adequately addressed the complexities of waste disposal and management [doc_id=KCDI000439, p.1].
#
# 3. **Decentralization Challenges**: The shift from centralized to decentralized waste management, prompted by widespread protests against landfill sites, has introduced new challenges. While decentralization aims to enhance local governance and community involvement, it has also led to conflicts in co-production of services. Initiatives like the Nirmala Bhavanam Nirmala Nagaram 2.0 (NBNN 2.0) campaign have faced socio-political and institutional barriers that hinder effective implementation [doc_id=KCDI000415, p.1; doc_id=KCDI000415, p.2].
#
# 4. **Institutional Capacity**: The capacity of local self-governments (LSGs) to manage waste effectively is often limited. Although the Kerala Municipalities Act, 1994, and the Solid Waste Management Rules, 2000, provide a framework for waste management, the actual execution of these policies is frequently hampered by inadequate resources and institutional support [doc_id=KCDI000415, p.1].
#
# 5. **Public Awareness and Education**: There is a significant gap in public awareness regarding waste management practices. The effectiveness of SWM initiatives is closely tied to the public's understanding and willingness to adopt responsible waste management practices. Without proper education and awareness campaigns, the community's ability to engage in sustainable waste management remains limited [doc_id=KCDI000439, p.1].
#
# In summary, the main challenges in solid waste management in Kerala municipalities include inadequate community participation, ineffective management models, challenges associated with decentralization, limited institutional capacity, and a lack of public awareness and education on waste management practices.
#
# **Sources Used**:
# 1. Centralized and decentralized approaches to solid waste management a case study_W4296392078.pdf
# 2. Exploring Community Attitudes and Perceptions Towards Solid Waste Management A Case Study of Kerala
# 3. Coping with conflicts in the co-production of solid waste management services experience with a real
#
# ----------------------------------------
# Retrieved Sources (ranked by relevance):
#   [1] KCDI000058 p.1 (score=6.772) — Centralized anddecentralized approaches to solid waste management  a case study_W4296392078.pdf
#   [2] KCDI000439 p.1 (score=4.821) — Exploring Community Attitudes and Perceptions Towards Solid Waste Management A Case Study of Kerala _W4406182745.pdf
#   [3] KCDI000415 p.1 (score=4.296) — Coping with conflicts in the co-production of solid waste management services experience with a real_W4413398266.pdf
#   [4] KCDI000415 p.2 (score=4.224) — Coping with conflicts in the co-production of solid waste management services experience with a real_W4413398266.pdf
#   [5] KCDI000415 p.1 (score=3.614) — Coping with conflicts in the co-production of solid waste management services experience with a real_W4413398266.pdf
#
#
#
# ================================================================================
# QUESTION: How do studies measure road congestion or traffic conditions in Indian cities?
# ================================================================================
#
# Studies measuring road congestion or traffic conditions in Indian cities employ various methodologies and performance measures to quantify congestion effectively. The following approaches are commonly utilized:
#
# 1. **Travel Time-Based Measures**: Many studies prioritize travel time as a key metric for assessing congestion. This involves using performance measures that focus on the time taken for vehicles to traverse specific routes. For instance, GPS-fitted public transit buses are increasingly used as probes to collect travel time data, allowing researchers to estimate congestion levels for different vehicle types in urban traffic streams [doc_id=KCDI000361, p.1]. This method is particularly advantageous in heterogeneous traffic environments where personal vehicles may not be suitable for data collection.
#
# 2. **Congestion Indices**: Researchers often develop congestion indices (CIs) that quantify the level of congestion based on various parameters, including vehicle dwell times at stops, acceleration, and deceleration times. These indices provide a comprehensive view of traffic conditions and help in identifying congestion hotspots [doc_id=KCDI000361, p.3].
#
# 3. **Level of Service (LOS) and Lane-Mile Duration Index**: Studies also utilize traditional metrics such as the Level of Service (LOS) and lane-mile duration index to evaluate congestion. These measures assess the quality of traffic flow and the extent to which road capacity is being utilized [doc_id=KCDI000045, p.1].
#
# 4. **Buffer Index**: The Buffer Index is another tool used to analyze congestion levels on selected road networks. It helps in understanding the variability in travel times and the impact of congestion on commuters [doc_id=KCDI000045, p.8].
#
# 5. **Congestion Pricing Techniques**: Some studies suggest the implementation of congestion pricing as a strategy to manage and reduce traffic congestion. This approach involves charging drivers for road usage during peak times to incentivize alternative transportation methods and reduce overall traffic volume [doc_id=KCDI000045, p.1].
#
# 6. **Heterogeneous Traffic Analysis**: Given the diverse nature of traffic in Indian cities, studies often focus on the unique characteristics of urban traffic, which includes a mix of two-wheelers, four-wheelers, and public transport. This complexity necessitates tailored methodologies that account for the varying behaviors and interactions of different vehicle types [doc_id=KCDI000045, p.1; doc_id=KCDI000361, p.3].
#
# In summary, the measurement of road congestion in Indian cities is multifaceted, incorporating travel time analysis, congestion indices, traditional performance measures, and innovative data collection methods using public transit systems. These approaches aim to provide a clearer understanding of traffic conditions and inform effective congestion management strategies.
#
# **Sources Used**:
# 1. Can we walk Environmental supports for physical activity in India_W2522998244.pdf
# 2. Assessment of Traffic Congestion under Indian Environment - a Case Study_W4297338610.pdf
# 3. Traffic Congestion Quantification for Urban Heterogeneous Traffic Using Public Transit Buses as Probes_W4297338610.pdf
#
# ----------------------------------------
# Retrieved Sources (ranked by relevance):
#   [1] KCDI000053 p.15 (score=4.508) — Can we walk Environmental supports for physical activity in India_W2522998244.pdf
#   [2] KCDI000045 p.8 (score=4.432) — Assessment of Traffic Congestion under Indian Environment - a Case Study_W4297338610.pdf
#   [3] KCDI000361 p.1 (score=4.349) — Traffic Congestion Quantification for Urban Heterogeneous Traffic Using Public Transit Buses as Prob_W2784965817.pdf
#   [4] KCDI000045 p.1 (score=3.746) — Assessment of Traffic Congestion under Indian Environment - a Case Study_W4297338610.pdf
#   [5] KCDI000361 p.3 (score=3.658) — Traffic Congestion Quantification for Urban Heterogeneous Traffic Using Public Transit Buses as Prob_W2784965817.pdf
#
#
#
# ================================================================================
# QUESTION: What role do gram panchayats play in local governance and decentralization?
# ================================================================================
#
# Gram panchayats serve as fundamental units of local governance in Kerala, playing a pivotal role in the decentralized planning and implementation of development initiatives. The framework established by the People's Plan has significantly empowered gram panchayats, granting them substantial authority to make decisions regarding local development. This empowerment is evident in their ability to identify and pursue projects, such as small hydro power (SHP) initiatives, which are crucial for rural electrification and sustainable energy development. The panchayats have the authority to conduct surveys and prepare Detailed Project Reports (DPRs) using their development funds, thereby actively participating in local economic development [Source 1, p.4].
#
# Moreover, gram panchayats are positioned as key players in addressing climate change at the grassroots level. They are encouraged to formulate locally-driven projects that integrate various sectoral programs from central and state government agencies. This involvement not only enhances their governance capabilities but also fosters community engagement in climate adaptation strategies [Source 2, p.10; Source 4, p.7]. The decentralized governance model allows for a more responsive and participatory approach, enabling citizens to engage in climate planning processes and enhancing the overall effectiveness of local governance [Source 2, p.10].
#
# The decentralized approach also emphasizes community ownership and responsibility, particularly in areas such as solid waste management. By involving citizens in the management of municipal solid waste, gram panchayats can foster a sense of ownership and accountability, which is crucial for the success of local governance initiatives [Source 3, p.3].
#
# In summary, gram panchayats in Kerala play a critical role in local governance and decentralization by:
# 1. Empowering local decision-making and project implementation.
# 2. Facilitating community engagement in climate adaptation and development initiatives.
# 3. Promoting ownership and responsibility among citizens in local governance processes.
#
# Sources Used:
# - Techno-Economic Analysis of Decentralised Small Hydro Power Projects for Rural Electrification A Case Study (KCDI000330)
# - LOCAL SELF-GOVERNMENT INSTITUTIONS AND CLIMATE CHANGE THE CASE OF MEENANGADI PANCHAYAT IN KERALA (KCDI000467)
# - Centralized and Decentralized Approaches to Solid Waste Management: A Case Study (KCDI000058)
#
# ----------------------------------------
# Retrieved Sources (ranked by relevance):
#   [1] KCDI000330 p.4 (score=2.353) — Techno-Economic Analysis of Decentralised Small Hydro Power Projects for Rural Electrification A Cas_W3134171003.pdf
#   [2] KCDI000467 p.10 (score=2.333) — LOCAL SELF-GOVERNMENT INSTITUTIONS AND CLIMATE CHANGE THE CASE OF MEENANGADI PANCHAYAT IN KERALA_W4392295590.pdf
#   [3] KCDI000058 p.3 (score=1.578) — Centralized anddecentralized approaches to solid waste management  a case study_W4296392078.pdf
#   [4] KCDI000467 p.7 (score=0.522) — LOCAL SELF-GOVERNMENT INSTITUTIONS AND CLIMATE CHANGE THE CASE OF MEENANGADI PANCHAYAT IN KERALA_W4392295590.pdf
#   [5] KCDI000229 p.2 (score=-0.429) — Municipal finance analysis The case study of Gujarat India_W3119711116.pdf
#
#
#
# ================================================================================
# QUESTION: What indicators measure electricity or water service reliability in Kerala?
# ================================================================================
#
# The provided sources do not specifically mention indicators that measure electricity service reliability in Kerala. However, they do provide insights into the measurement of water service reliability, particularly in the context of rural water supply schemes.
#
# In the study on the sustainability of demand-responsive approaches to rural water supply in Kerala, performance indicators were developed to assess the effectiveness of these schemes. The findings indicated that community-driven water supply schemes, such as the Jalanidhi schemes, were more successful in delivering adequate and reliable water supply compared to traditional supply-driven models. The study highlighted several indices that reflect the performance of water supply schemes, including:
#
# 1. **Availability & Reliability Index**: This index measures the consistency and dependability of water supply to households.
# 2. **Household Satisfaction Index**: This index gauges consumer satisfaction with the quality and reliability of the water service.
# 3. **Operation & Maintenance Index**: This index assesses the effectiveness of the operational and maintenance practices in place for water supply systems.
# 4. **Institutional Sustainability Index**: This index evaluates the long-term viability of the water supply schemes in terms of governance and community involvement [doc_id=KCDI000322, p.23].
#
# These indices collectively provide a framework for measuring the reliability of water services in Kerala, emphasizing the importance of community participation and the effectiveness of management practices in ensuring consistent service delivery.
#
# In summary, while specific indicators for electricity service reliability are not discussed in the sources, the water service reliability indicators provide a relevant framework for understanding how service reliability can be measured in community-managed contexts in Kerala.
#
# **Sources Used**
# - Monitoring Universal Health Coverage reforms in primary health care facilities Creating a framework
# - Sustainability of demand responsive approaches to rural water supply the case of Kerala_W3122568132
#
# ----------------------------------------
# Retrieved Sources (ranked by relevance):
#   [1] KCDI000224 p.11 (score=2.433) — Monitoring Universal Health Coverage reforms in primary health care facilities Creating a framework _W3047303743.pdf
#   [2] KCDI000322 p.2 (score=2.173) — Sustainability of demand responsive approaches to rural water supply  the case of Kerala_W3122568132.pdf
#   [3] KCDI000224 p.8 (score=2.059) — Monitoring Universal Health Coverage reforms in primary health care facilities Creating a framework _W3047303743.pdf
#   [4] KCDI000322 p.23 (score=1.595) — Sustainability of demand responsive approaches to rural water supply  the case of Kerala_W3122568132.pdf
#   [5] KCDI000141 p.11 (score=0.797) — Farm Tourism in Kerala  An Empirical Analysis of Service Quality_W4390712297.pdf

# %% [markdown]
# # --- EVALUATION SECTION ---
# ## Step 7: Build evaluation dataset and run RAGAS metrics
#
# The cells below let you:
# 1. Define ground-truth Q&A pairs with expected source doc_ids
# 2. Run retrieval metrics (Hit Rate, MRR)
# 3. Run generation metrics via RAGAS (faithfulness, relevancy, context precision/recall)

# %%
# ============================================================
# STEP 7a: Evaluation Dataset (Ground Truth)
# ============================================================
# Fill in expected_doc_ids with doc_ids you KNOW should be retrieved.
# Start with 10-15 and grow to 30-50 as you review results.
# You can find relevant doc_ids by running rag_query and checking which
# sources are returned — then verify if those are correct.

eval_dataset = [
    {
        "question": "What indicators are used to measure municipal service delivery performance in Kerala?",
        "expected_doc_ids": [],   # <-- fill in after reviewing results, e.g. ["KCDI000045", "KCDI000112"]
        "ground_truth_answer": "" # <-- optional: write a short reference answer
    },
    {
        "question": "How does Kudumbashree contribute to women's empowerment?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
    {
        "question": "What are the challenges in solid waste management in Kerala municipalities?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
    {
        "question": "What role do gram panchayats play in decentralized governance?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
    {
        "question": "How is literacy rate measured across Kerala districts?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
    {
        "question": "What are the main sources of revenue for local self-government institutions in Kerala?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
    {
        "question": "How do studies measure housing quality or housing conditions in Indian cities?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
    {
        "question": "What is the impact of MGNREGA on rural employment in Kerala?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
    {
        "question": "How is drinking water access measured at the ward or panchayat level?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
    {
        "question": "What are the health indicators used in community development indices?",
        "expected_doc_ids": [],
        "ground_truth_answer": ""
    },
]

print(f"Evaluation dataset: {len(eval_dataset)} questions")
print("NOTE: Fill in expected_doc_ids after reviewing initial results!")
# Out:
# Evaluation dataset: 10 questions
# NOTE: Fill in expected_doc_ids after reviewing initial results!

# %%
# ============================================================
# STEP 7b: Retrieval Metrics (Hit Rate, MRR)
# ============================================================
# These measure whether the correct documents appear in the top-k results.
# Only works once you fill in expected_doc_ids above.

def evaluate_retrieval(eval_data, top_k=6):
    """Compute Hit Rate@k and MRR@k for the evaluation dataset."""
    hit_rates = []
    mrrs = []

    for item in eval_data:
        expected = set(item["expected_doc_ids"])
        if not expected:
            continue  # skip items without ground truth

        docs = retrieve_and_rerank(item["question"], top_k=top_k)
        retrieved_ids = [d.metadata.get("doc_id") for d in docs]

        # Hit Rate: was ANY expected doc in the top-k?
        hit = any(rid in expected for rid in retrieved_ids)
        hit_rates.append(1.0 if hit else 0.0)

        # MRR: reciprocal rank of the first expected doc found
        rr = 0.0
        for rank, rid in enumerate(retrieved_ids, 1):
            if rid in expected:
                rr = 1.0 / rank
                break
        mrrs.append(rr)

    if not hit_rates:
        print("No evaluation items have expected_doc_ids filled in yet!")
        return

    print(f"Evaluated {len(hit_rates)} questions at top_k={top_k}")
    print(f"  Hit Rate@{top_k}: {np.mean(hit_rates):.3f}")
    print(f"  MRR@{top_k}:      {np.mean(mrrs):.3f}")

    return {"hit_rate": np.mean(hit_rates), "mrr": np.mean(mrrs)}

# Run it (will only produce results once expected_doc_ids are filled in)
evaluate_retrieval(eval_dataset, top_k=6)
# Out:
# No evaluation items have expected_doc_ids filled in yet!

# %%
# ============================================================
# STEP 7c: RAGAS Evaluation (Faithfulness, Relevancy, etc.)
# ============================================================
# RAGAS uses an LLM (OpenAI) to automatically evaluate RAG quality.
# It measures:
#   - faithfulness: is the answer grounded in the retrieved context?
#   - answer_relevancy: does it actually answer the question?
#   - context_precision: are the retrieved chunks relevant?
#   - context_recall: did we retrieve all the needed context?
#     (requires ground_truth_answer to be filled in)

from ragas import evaluate
from ragas.metrics import faithfulness, answer_relevancy, context_precision, context_recall
from datasets import Dataset

def run_ragas_evaluation(eval_data, top_k=6):
    """Run RAGAS evaluation over the eval dataset."""
    questions = []
    answers = []
    contexts = []
    ground_truths = []

    for item in eval_data:
        q = item["question"]
        result = rag_query(q, top_k=top_k, verbose=False)

        questions.append(q)
        answers.append(result["answer"])
        contexts.append([d.page_content for d in result["docs"]])

        gt = item.get("ground_truth_answer", "")
        ground_truths.append(gt if gt else result["answer"])  # fallback to generated answer

    # Build HuggingFace Dataset
    ds = Dataset.from_dict({
        "question": questions,
        "answer": answers,
        "contexts": contexts,
        "ground_truth": ground_truths,
    })

    # Choose metrics (context_recall needs ground_truth to be meaningful)
    metrics = [faithfulness, answer_relevancy, context_precision]
    if any(item.get("ground_truth_answer") for item in eval_data):
        metrics.append(context_recall)

    # Run evaluation
    print(f"Running RAGAS evaluation on {len(questions)} questions...")
    result = evaluate(ds, metrics=metrics)

    print("\n--- RAGAS Results ---")
    for metric_name, score in result.items():
        print(f"  {metric_name}: {score:.4f}")

    return result

# Run it
ragas_results = run_ragas_evaluation(eval_dataset, top_k=6)
# Out:
# Running RAGAS evaluation on 10 questions...
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]
# --- RAGAS Results ---
#   faithfulness: 0.9008
#   answer_relevancy: 0.8662
#   context_precision: 0.9403

# %%
# ============================================================
# STEP 8: Export data for Streamlit app deployment
# ============================================================
# This cell packages everything the app needs into a single zip file.
# After running, download rag_app_data.zip and unzip into your repo's data/ folder.

import pickle
import shutil

EXPORT_DIR = "/content/rag_app_export"
os.makedirs(EXPORT_DIR, exist_ok=True)

# 1. Save chunk_docs WITHOUT parent_text (saves ~80% space)
export_chunks = []
for doc in chunk_docs:
    meta = {k: v for k, v in doc.metadata.items() if k != "parent_text"}
    export_chunks.append(Document(page_content=doc.page_content, metadata=meta))

with open(os.path.join(EXPORT_DIR, "chunk_docs.pkl"), "wb") as f:
    pickle.dump(export_chunks, f)
print(f"Saved {len(export_chunks)} chunks to chunk_docs.pkl")

# 2. Copy FAISS index files
faiss_src = os.path.join(BASE_DIR, "faiss_index_bge_base")
faiss_dst = os.path.join(EXPORT_DIR, "faiss_index_bge_base")
if os.path.isdir(faiss_dst):
    shutil.rmtree(faiss_dst)
shutil.copytree(faiss_src, faiss_dst)
print(f"Copied FAISS index to export folder")

# 3. Copy manifest for metadata lookups
shutil.copy2(MANIFEST_PATH, os.path.join(EXPORT_DIR, "manifest_final.csv"))
print("Copied manifest_final.csv")

# 4. Zip everything
shutil.make_archive("/content/rag_app_data", "zip", EXPORT_DIR)
print(f"\nDOWNLOAD: /content/rag_app_data.zip")
print("Unzip the contents into your repo's data/ folder.")

# Show sizes
for root, dirs, files in os.walk(EXPORT_DIR):
    for f in files:
        fp = os.path.join(root, f)
        size_mb = os.path.getsize(fp) / (1024 * 1024)
        print(f"  {os.path.relpath(fp, EXPORT_DIR)}: {size_mb:.1f} MB")
